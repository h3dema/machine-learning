# %% [markdown]
# # Gradient Descent utilizando sklearn
# Exemplo com 4 features
#
# Author: H3dema

# %%
import numpy as np
from sklearn import linear_model
from sklearn.datasets import make_regression

# %matplotlib inline  
from matplotlib import pyplot as py

# %%
# gera uma conjunto de dados (aprox. reta) aleatoriamente
n = 150  # numero de pontos (exemplos)
m = 4  # numero de características

x_values, y_values = make_regression(n_samples=n, n_features=m, random_state=0, coef=False)

# %%
print "num features:", m
for i in range(m):
    py.plot(x_values[:,i], y_values, 'ro')
    py.xlabel("variavel %d" % (i+1))
    py.show()
# Out:
# num features: 4

# %% [markdown]
# # criando o regressor

# %%
max_iter = 20  # número máximo de iterações

clf = linear_model.SGDRegressor(max_iter=max_iter,
                                loss='squared_loss')

# %%
clf.fit(x_values, y_values)
# Out:
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', max_iter=20, n_iter=None, penalty='l2',
#        power_t=0.25, random_state=None, shuffle=True, tol=None, verbose=0,
#        warm_start=False)

# %%
print "Intercept  :", clf.intercept_
print "Coeficients:", clf.coef_
# Out:
# Intercept  : [-0.27000691]
# Coeficients: [ 59.41947501  11.83510951  24.5114486   56.81825419]

# %%
print "Coef. Determinacao (r²):", clf.score(x_values, y_values)
# Out:
# Coef. Determinacao (r²): 0.999987066929

# %%
erro = clf.predict(x_values)-y_values
print "Erro médio : ", np.mean(erro)
print "Erro mínimo: ", np.min(erro)
print "Erro máximo: ", np.max(erro)
# Out:
# Erro médio :  -0.207071014478
# Erro mínimo:  -1.07069935109
# Erro máximo:  0.543307389023
